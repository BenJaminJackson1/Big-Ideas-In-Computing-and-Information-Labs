# %% [markdown]
# # LAB 1 BJJ47
# 1. Name:
# + Benjamin Jackson
# 2. Date:
# + 9/4/24

# %% [markdown]
# #Lab1 BJJ47

# %% [markdown]
# ## Markdown Exercises
# I am interested in code because I like to *create* things.
# I hope to be able to use coding to **better** society.
# I would like to learn **Javascript**, *html*, english, *how to live without my parents*, **and how coding can help others**

# %% [markdown]
# ![image description goes here](https://media.giphy.com/media/fUQ4rhUZJYiQsas6WD/giphy.gif?cid=790b7611zmq2dugtor3euwrz1hxr6suujk52nzjglanl36yz&ep=v1_gifs_trending&rid=giphy.gif&ct=g)

# %% [markdown]
# --- print("Hi! I'm a code cell. Try changing me.")

# %% [markdown]
# ## Jupyter Notebook Exercises

# %%
name = input(prompt="What is your name? ")
print("Hello", name, "!")
# Out:
# What is your name?  Ben
# Hello Ben !

# %% [markdown]
# The code cell printed "What is your name?" with a prompt. When I put it my name it said "Hello Ben !"

# %%
dude = input(prompt="What is your name? ")
print("Hello", name, "!")
# Out:
# What is your name?  Ben
# Hello Ben !

# %% [markdown]
# I changed name too dude; this did nothing and it worked.

# %%
# %matplotlib inline
import pandas as pd
# Load the PGH 311 Complaint data
data_url = \
"https://data.wprdc.org/datastore/dump/76fda9d0-69be-4dd5-8108-0de7907fc5a4"
complaints = pd.read_csv(data_url, parse_dates=True, index_col="CREATED_ON")
# Produce a graph that shows the number of complaints per month
complaints.resample("ME").size().plot();

# %%
import matplotlib.pyplot as plt
plt.show()

# %% [markdown]
# ![image description goes here](https://media.giphy.com/media/v1.Y2lkPTc5MGI3NjExem1xMmR1Z3RvcjNldXdyejFoeHI2c3V1ams1Mm56amdsYW5sMzZ5eiZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/yoJC2GnSClbPOkV0eA/giphy.gif)
